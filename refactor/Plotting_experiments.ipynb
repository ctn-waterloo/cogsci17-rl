# %%
# %matplotlib inline
import pandas
import pytry
import seaborn

# %%
data = pytry.read('data')

# %%
data2 = []
for d in data:
    stay = d['stay_prob']
    for rewarded in [True, False]:
        for rare in [True, False]:
            d2 = dict(d)
            d2['rewarded']=rewarded
            d2['rare']=rare
            d2['stay']=stay[rewarded,rare]
            data2.append(d2)

# %%
df = pandas.DataFrame(data2)

# %%
seaborn.barplot('rewarded', 'stay', hue='rare', data=df.query('seed==1 and direct==True and T_interval==0.2 and n_intervals==20000'), order=[1, 0])

# %%
seaborn.barplot('rewarded', 'stay', hue='rare', data=df.query('seed==1 and direct==False and T_interval==0.1 and n_intervals==20000'), order=[1, 0])

# %%
#g = seaborn.FacetGrid(data2, row="direct", col="T_interval")
#g = g.map(seaborn.barplot, "rewarded", "stay", hue="rare")
print seaborn.__version__
# Out:
# 0.7.1

# %%
seaborn.barplot('rewarded', 'stay', hue='rare', data=df.query('env_seed==2 and direct==True and T_interval==0.5 and n_intervals==20000'), order=[1, 0])

# %%
seaborn.barplot('rewarded', 'stay', hue='rare', data=df.query('env_seed==2 and direct==False and T_interval==0.5 and n_intervals==20000'), order=[1, 0])

# %%
#df.query('seed==1 and direct==False and T_interval==0.5 and n_intervals==20000')
