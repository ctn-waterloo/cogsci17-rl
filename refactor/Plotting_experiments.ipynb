# %%
# %matplotlib inline
import pandas
import pytry
import seaborn
import pylab

# %%
data = pytry.read('data')

# %%
data2 = []
for d in data:
    stay = d['stay_prob']
    for rewarded in [True, False]:
        for rare in [True, False]:
            d2 = dict(d)
            d2['rewarded']='+' if rewarded else '-'#rewarded
            d2['rare']='R' if rare else 'C'#rare
            d2['stay']=stay[int(rewarded),int(rare)]
            d2['type']='%s%s' % ('R' if rare else 'C', '+' if rewarded else '-')
            data2.append(d2)
            d2.pop('history')
            d2.pop('rewards')
            d2.pop('stay_prob')
df = pandas.DataFrame(data2)
df = df.drop_duplicates(subset=['seed', 'stay'])

# %%
#df = pandas.DataFrame(data2)
#print data2[0]
#print len(df.query('n_intervals==20000 and syn==0.025 and seed==4 and (T_interval==0.5 or T_interval==0.51) and N_product==200'))/4

seaborn.set_style("whitegrid")
pylab.figure(figsize=(4,3))

colors = seaborn.color_palette('deep', 2)
palette = {
    'C+': colors[0],
    'R+': colors[1],
    'C-': colors[0],
    'R-': colors[1],
}

# %%
#import numpy as np
#for k in df.keys():
#    if k != 'stay':
#        print (k, np.unique(getattr(df, k)))
#df.query('seed==1')
# Out:
#        D  N_product  N_state_action  T_interval  alpha backend  choice_noise  \
# 32     5        200            1000        0.05    0.3   nengo          0.05
# 33     5        200            1000        0.05    0.3   nengo          0.05
# 34     5        200            1000        0.05    0.3   nengo          0.05
# 35     5        200            1000        0.05    0.3   nengo          0.05
# 120    5       1000             100        0.05    0.3   nengo          0.05
# 121    5       1000             100        0.05    0.3   nengo          0.05
# 122    5       1000             100        0.05    0.3   nengo          0.05
# 123    5       1000             100        0.05    0.3   nengo          0.05
# 348    5        200             500        0.30    0.3   nengo          0.05
# 349    5        200             500        0.30    0.3   nengo          0.05
# 350    5        200             500        0.30    0.3   nengo          0.05
# 351    5        200             500        0.30    0.3   nengo          0.05
# 380    5       1000            1000        0.05    0.3   nengo          0.05
# 381    5       1000            1000        0.05    0.3   nengo          0.05
# 382    5       1000            1000        0.05    0.3   nengo          0.05
# 383    5       1000            1000        0.05    0.3   nengo          0.05
# 384    5        500             500        0.10    0.3   nengo          0.05
# 385    5        500             500        0.10    0.3   nengo          0.05
# 386    5        500             500        0.10    0.3   nengo          0.05
# 387    5        500             500        0.10    0.3   nengo          0.05
# 400    5        200             500        0.51    0.3   nengo          0.05
# 401    5        200             500        0.51    0.3   nengo          0.05
# 402    5        200             500        0.51    0.3   nengo          0.05
# 403    5        200             500        0.51    0.3   nengo          0.05
# 420    5       1000            1000        0.05    0.3   nengo          0.05
# 421    5       1000            1000        0.05    0.3   nengo          0.05
# 422    5       1000            1000        0.05    0.3   nengo          0.05
# 423    5       1000            1000        0.05    0.3   nengo          0.05
# 620    5        500             500        0.05    0.3   nengo          0.05
# 621    5        500             500        0.05    0.3   nengo          0.05
# ...   ..        ...             ...         ...    ...     ...           ...
# 16998  5        300             500        0.10    0.3   nengo          0.05
# 16999  5        300             500        0.10    0.3   nengo          0.05
# 17032  5        500             500        0.05    0.3   nengo          0.05
# 17033  5        500             500        0.05    0.3   nengo          0.05
# 17034  5        500             500        0.05    0.3   nengo          0.05
# 17035  5        500             500        0.05    0.3   nengo          0.05
# 17048  5       1000             500        0.20    0.3   nengo          0.05
# 17049  5       1000             500        0.20    0.3   nengo          0.05
# 17050  5       1000             500        0.20    0.3   nengo          0.05
# 17051  5       1000             500        0.20    0.3   nengo          0.05
# 17496  5        100            1000        0.05    0.3   nengo          0.05
# 17497  5        100            1000        0.05    0.3   nengo          0.05
# 17498  5        100            1000        0.05    0.3   nengo          0.05
# 17499  5        100            1000        0.05    0.3   nengo          0.05
# 17572  5        500             500        0.20    0.3   nengo          0.05
# 17573  5        500             500        0.20    0.3   nengo          0.05
# 17574  5        500             500        0.20    0.3   nengo          0.05
# 17575  5        500             500        0.20    0.3   nengo          0.05
# 17644  5        300             500        0.05    0.3   nengo          0.05
# 17645  5        300             500        0.05    0.3   nengo          0.05
# 17646  5        300             500        0.05    0.3   nengo          0.05
# 17647  5        300             500        0.05    0.3   nengo          0.05
# 17728  5        200             500        0.05    0.3   nengo          0.05
# 17729  5        200             500        0.05    0.3   nengo          0.05
# 17730  5        200             500        0.05    0.3   nengo          0.05
# 17731  5        200             500        0.05    0.3   nengo          0.05
# 17848  5       1000             500        0.10    0.3   nengo          0.05
# 17849  5       1000             500        0.10    0.3   nengo          0.05
# 17850  5       1000             500        0.10    0.3   nengo          0.05
# 17851  5       1000             500        0.10    0.3   nengo          0.05
#
#       direct     dt  env_seed  n_intervals neuron_type rare   rate rewarded  \
# 32     False  0.001        21        20000     default    R  False        +
# 33     False  0.001        21        20000     default    C  False        +
# 34     False  0.001        21        20000     default    R  False        -
# 35     False  0.001        21        20000     default    C  False        -
# 120    False  0.001        21        20000     default    R  False        +
# 121    False  0.001        21        20000     default    C  False        +
# 122    False  0.001        21        20000     default    R  False        -
# 123    False  0.001        21        20000     default    C  False        -
# 348    False  0.001        23        20000     default    R  False        +
# 349    False  0.001        23        20000     default    C  False        +
# 350    False  0.001        23        20000     default    R  False        -
# 351    False  0.001        23        20000     default    C  False        -
# 380    False  0.001        21        20000     default    R  False        +
# 381    False  0.001        21        20000     default    C  False        +
# 382    False  0.001        21        20000     default    R  False        -
# 383    False  0.001        21        20000     default    C  False        -
# 384    False  0.001        22        20000     default    R  False        +
# 385    False  0.001        22        20000     default    C  False        +
# 386    False  0.001        22        20000     default    R  False        -
# 387    False  0.001        22        20000     default    C  False        -
# 400    False  0.001        23        20000     default    R  False        +
# 401    False  0.001        23        20000     default    C  False        +
# 402    False  0.001        23        20000     default    R  False        -
# 403    False  0.001        23        20000     default    C  False        -
# 420    False  0.001        21        20000     default    R  False        +
# 421    False  0.001        21        20000     default    C  False        +
# 422    False  0.001        21        20000     default    R  False        -
# 423    False  0.001        21        20000     default    C  False        -
# 620    False  0.001        22        20000     default    R  False        +
# 621    False  0.001        22        20000     default    C  False        +
# ...      ...    ...       ...          ...         ...  ...    ...      ...
# 16998  False  0.001        22        20000     default    R  False        -
# 16999  False  0.001        22        20000     default    C  False        -
# 17032  False  0.001        21        20000     default    R  False        +
# 17033  False  0.001        21        20000     default    C  False        +
# 17034  False  0.001        21        20000     default    R  False        -
# 17035  False  0.001        21        20000     default    C  False        -
# 17048  False  0.001        22        20000     default    R  False        +
# 17049  False  0.001        22        20000     default    C  False        +
# 17050  False  0.001        22        20000     default    R  False        -
# 17051  False  0.001        22        20000     default    C  False        -
# 17496  False  0.001        21        20000     default    R  False        +
# 17497  False  0.001        21        20000     default    C  False        +
# 17498  False  0.001        21        20000     default    R  False        -
# 17499  False  0.001        21        20000     default    C  False        -
# 17572  False  0.001        22        20000     default    R  False        +
# 17573  False  0.001        22        20000     default    C  False        +
# 17574  False  0.001        22        20000     default    R  False        -
# 17575  False  0.001        22        20000     default    C  False        -
# 17644  False  0.001        21        20000     default    R  False        +
# 17645  False  0.001        21        20000     default    C  False        +
# 17646  False  0.001        21        20000     default    R  False        -
# 17647  False  0.001        21        20000     default    C  False        -
# 17728  False  0.001        22        20000     default    R  False        +
# 17729  False  0.001        22        20000     default    C  False        +
# 17730  False  0.001        22        20000     default    R  False        -
# 17731  False  0.001        22        20000     default    C  False        -
# 17848  False  0.001        22        20000     default    R  False        +
# 17849  False  0.001        22        20000     default    C  False        +
# 17850  False  0.001        22        20000     default    R  False        -
# 17851  False  0.001        22        20000     default    C  False        -
#
#        seed      stay                                          stay_prob  \
# 32        1  0.815807  [[0.80088217, 0.93821571], [0.88109162, 0.8158...
# 33        1  0.881092  [[0.80088217, 0.93821571], [0.88109162, 0.8158...
# 34        1  0.938216  [[0.80088217, 0.93821571], [0.88109162, 0.8158...
# 35        1  0.800882  [[0.80088217, 0.93821571], [0.88109162, 0.8158...
# 120       1  0.651207  [[0.543125, 0.69750603], [0.69385027, 0.651207...
# 121       1  0.693850  [[0.543125, 0.69750603], [0.69385027, 0.651207...
# 122       1  0.697506  [[0.543125, 0.69750603], [0.69385027, 0.651207...
# 123       1  0.543125  [[0.543125, 0.69750603], [0.69385027, 0.651207...
# 348       1  0.543978  [[0.54234001, 0.8335028], [0.81714668, 0.54397...
# 349       1  0.817147  [[0.54234001, 0.8335028], [0.81714668, 0.54397...
# 350       1  0.833503  [[0.54234001, 0.8335028], [0.81714668, 0.54397...
# 351       1  0.542340  [[0.54234001, 0.8335028], [0.81714668, 0.54397...
# 380       1  0.844816  [[0.82732686, 0.94970572], [0.90177983, 0.8448...
# 381       1  0.901780  [[0.82732686, 0.94970572], [0.90177983, 0.8448...
# 382       1  0.949706  [[0.82732686, 0.94970572], [0.90177983, 0.8448...
# 383       1  0.827327  [[0.82732686, 0.94970572], [0.90177983, 0.8448...
# 384       1  0.458578  [[0.55124125, 0.82662457], [0.74589626, 0.4585...
# 385       1  0.745896  [[0.55124125, 0.82662457], [0.74589626, 0.4585...
# 386       1  0.826625  [[0.55124125, 0.82662457], [0.74589626, 0.4585...
# 387       1  0.551241  [[0.55124125, 0.82662457], [0.74589626, 0.4585...
# 400       1  0.576766  [[0.54711444, 0.83135572], [0.8478986, 0.57676...
# 401       1  0.847899  [[0.54711444, 0.83135572], [0.8478986, 0.57676...
# 402       1  0.831356  [[0.54711444, 0.83135572], [0.8478986, 0.57676...
# 403       1  0.547114  [[0.54711444, 0.83135572], [0.8478986, 0.57676...
# 420       1  0.675676  [[0.67607441, 0.92364209], [0.87636832, 0.6756...
# 421       1  0.876368  [[0.67607441, 0.92364209], [0.87636832, 0.6756...
# 422       1  0.923642  [[0.67607441, 0.92364209], [0.87636832, 0.6756...
# 423       1  0.676074  [[0.67607441, 0.92364209], [0.87636832, 0.6756...
# 620       1  0.547320  [[0.46508035, 0.61855948], [0.66860841, 0.5473...
# 621       1  0.668608  [[0.46508035, 0.61855948], [0.66860841, 0.5473...
# ...     ...       ...                                                ...
# 16998     1  0.818539  [[0.58386684, 0.81853888], [0.77453581, 0.6162...
# 16999     1  0.583867  [[0.58386684, 0.81853888], [0.77453581, 0.6162...
# 17032     1  0.920798  [[0.87837838, 0.94849213], [0.90243902, 0.9207...
# 17033     1  0.902439  [[0.87837838, 0.94849213], [0.90243902, 0.9207...
# 17034     1  0.948492  [[0.87837838, 0.94849213], [0.90243902, 0.9207...
# 17035     1  0.878378  [[0.87837838, 0.94849213], [0.90243902, 0.9207...
# 17048     1  0.544977  [[0.53288201, 0.83363707], [0.81409002, 0.5449...
# 17049     1  0.814090  [[0.53288201, 0.83363707], [0.81409002, 0.5449...
# 17050     1  0.833637  [[0.53288201, 0.83363707], [0.81409002, 0.5449...
# 17051     1  0.532882  [[0.53288201, 0.83363707], [0.81409002, 0.5449...
# 17496     1  0.599331  [[0.58643744, 0.80649419], [0.76507937, 0.5993...
# 17497     1  0.765079  [[0.58643744, 0.80649419], [0.76507937, 0.5993...
# 17498     1  0.806494  [[0.58643744, 0.80649419], [0.76507937, 0.5993...
# 17499     1  0.586437  [[0.58643744, 0.80649419], [0.76507937, 0.5993...
# 17572     1  0.520053  [[0.53877423, 0.83738318], [0.78974359, 0.5200...
# 17573     1  0.789744  [[0.53877423, 0.83738318], [0.78974359, 0.5200...
# 17574     1  0.837383  [[0.53877423, 0.83738318], [0.78974359, 0.5200...
# 17575     1  0.538774  [[0.53877423, 0.83738318], [0.78974359, 0.5200...
# 17644     1  0.892377  [[0.80915318, 0.93112725], [0.85685885, 0.8923...
# 17645     1  0.856859  [[0.80915318, 0.93112725], [0.85685885, 0.8923...
# 17646     1  0.931127  [[0.80915318, 0.93112725], [0.85685885, 0.8923...
# 17647     1  0.809153  [[0.80915318, 0.93112725], [0.85685885, 0.8923...
# 17728     1  0.897319  [[0.81286913, 0.93129361], [0.87033399, 0.8973...
# 17729     1  0.870334  [[0.81286913, 0.93129361], [0.87033399, 0.8973...
# 17730     1  0.931294  [[0.81286913, 0.93129361], [0.87033399, 0.8973...
# 17731     1  0.812869  [[0.81286913, 0.93129361], [0.87033399, 0.8973...
# 17848     1  0.460823  [[0.5671406, 0.83642139], [0.7483871, 0.460823...
# 17849     1  0.748387  [[0.5671406, 0.83642139], [0.7483871, 0.460823...
# 17850     1  0.836421  [[0.5671406, 0.83642139], [0.7483871, 0.460823...
# 17851     1  0.567141  [[0.5671406, 0.83642139], [0.7483871, 0.460823...
#
#          syn type
# 32     0.010   R+
# 33     0.010   C+
# 34     0.010   R-
# 35     0.010   C-
# 120    0.010   R+
# 121    0.010   C+
# 122    0.010   R-
# 123    0.010   C-
# 348    0.017   R+
# 349    0.017   C+
# 350    0.017   R-
# 351    0.017   C-
# 380    0.010   R+
# 381    0.010   C+
# 382    0.010   R-
# 383    0.010   C-
# 384    0.005   R+
# 385    0.005   C+
# 386    0.005   R-
# 387    0.005   C-
# 400    0.025   R+
# 401    0.025   C+
# 402    0.025   R-
# 403    0.025   C-
# 420    0.005   R+
# 421    0.005   C+
# 422    0.005   R-
# 423    0.005   C-
# 620    0.001   R+
# 621    0.001   C+
# ...      ...  ...
# 16998  0.025   R-
# 16999  0.025   C-
# 17032  0.017   R+
# 17033  0.017   C+
# 17034  0.017   R-
# 17035  0.017   C-
# 17048  0.010   R+
# 17049  0.010   C+
# 17050  0.010   R-
# 17051  0.010   C-
# 17496  0.005   R+
# 17497  0.005   C+
# 17498  0.005   R-
# 17499  0.005   C-
# 17572  0.010   R+
# 17573  0.010   C+
# 17574  0.010   R-
# 17575  0.010   C-
# 17644  0.017   R+
# 17645  0.017   C+
# 17646  0.017   R-
# 17647  0.017   C-
# 17728  0.017   R+
# 17729  0.017   C+
# 17730  0.017   R-
# 17731  0.017   C-
# 17848  0.005   R+
# 17849  0.005   C+
# 17850  0.005   R-
# 17851  0.005   C-
#
# [875 rows x 20 columns]

# %%
seaborn.barplot('rewarded', 'stay', hue='rare', data=df.query('T_interval==0.1 and n_intervals==20000 and syn==0.017 and seed==3 and N_product==500'), order=[True, False])

# %%
seaborn.barplot('rewarded', 'stay', hue='rare', data=df.query('T_interval==0.2 and n_intervals==20000 and syn==0.017 and seed==3 and N_product==500'), order=[True, False])

# %%
#g = seaborn.FacetGrid(data2, row="direct", col="T_interval")
#g = g.map(seaborn.barplot, "rewarded", "stay", hue="rare")
#print seaborn.__version__
print df.query('direct==False and T_interval==0.1 and n_intervals==20000 and N_state_action==50 and alpha==0.3 and seed==1').shape
# Out:
# (0, 19)

# %%
seaborn.barplot('rewarded', 'stay', hue='rare', data=df.query('n_intervals==20000 and syn==0.1 and seed==1'), order=[True, False])

# %%
seaborn.barplot('rewarded', 'stay', hue='rare', data=df.query('n_intervals==20000 and syn==0.017 and seed==18 and (T_interval==0.2 or T_interval==0.3) and N_product==200'), order=[True, False])

# %%
seaborn.barplot('rewarded', 'stay', hue='rare', data=df.query('T_interval==0.5 and n_intervals==20000 and syn==0.049 and seed==3'), order=[True, False])

# %%
seaborn.barplot('rewarded', 'stay', hue='rare', data=df.query('T_interval==0.5 and n_intervals==20000 and syn==0.049 and seed==4'), order=[True, False])

# %%
seaborn.barplot('rewarded', 'stay', hue='rare', data=df.query('T_interval==0.5 and n_intervals==20000 and syn==0.049 and seed==5'), order=[True, False])

# %%
seaborn.barplot('rewarded', 'stay', hue='rare', data=df.query('T_interval==0.5 and n_intervals==20000 and syn==0.049 and seed==6'), order=[True, False])

# %%
seaborn.barplot('rewarded', 'stay', hue='rare', data=df.query('T_interval==0.5 and n_intervals==20000 and syn==0.049 and seed==6'), order=[True, False])

# %%
seaborn.barplot('rewarded', 'stay', hue='rare', data=df.query('T_interval==0.5 and n_intervals==20000 and syn==0.049 and seed==7'), order=[True, False])

# %%
seaborn.barplot('rewarded', 'stay', hue='rare', data=df.query('rate==True and env_seed==1 and T_interval==0.002 and n_intervals==20000 and N_state_action==500 and alpha==0.8'), order=[True, False])
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-7-31b24712aeae> in <module>()
# ----> 1 seaborn.barplot('rewarded', 'stay', hue='rare', data=df.query('rate==True and env_seed==1 and T_interval==0.002 and n_intervals==20000 and N_state_action==500 and alpha==0.8'), order=[True, False])
#
# /usr/local/lib/python2.7/dist-packages/seaborn/categorical.pyc in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, ax, **kwargs)
#    2897                           estimator, ci, n_boot, units,
#    2898                           orient, color, palette, saturation,
# -> 2899                           errcolor, errwidth, capsize)
#    2900
#    2901     if ax is None:
#
# /usr/local/lib/python2.7/dist-packages/seaborn/categorical.pyc in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize)
#    1541         """Initialize the plotter."""
#    1542         self.establish_variables(x, y, hue, data, orient,
# -> 1543                                  order, hue_order, units)
#    1544         self.establish_colors(color, palette, saturation)
#    1545         self.estimate_statistic(estimator, ci, n_boot)
#
# /usr/local/lib/python2.7/dist-packages/seaborn/categorical.pyc in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     201                 # Group the numeric data
#     202                 plot_data, value_label = self._group_longform(vals, groups,
# --> 203                                                               group_names)
#     204
#     205                 # Now handle the hue levels for nested ordering
#
# /usr/local/lib/python2.7/dist-packages/seaborn/categorical.pyc in _group_longform(self, vals, grouper, order)
#     247         for g in order:
#     248             try:
# --> 249                 g_vals = np.asarray(grouped_vals.get_group(g))
#     250             except KeyError:
#     251                 g_vals = np.array([])
#
# /usr/lib/python2.7/dist-packages/pandas/core/groupby.pyc in get_group(self, name, obj)
#     571             obj = self._selected_obj
#     572
# --> 573         inds = self._get_index(name)
#     574         return obj.take(inds, axis=self.axis, convert=False)
#     575
#
# /usr/lib/python2.7/dist-packages/pandas/core/groupby.pyc in _get_index(self, name)
#     427             return key
#     428
# --> 429         sample = next(iter(self.indices))
#     430         if isinstance(sample, tuple):
#     431             if not isinstance(name, tuple):
#
# StopIteration:

# %%
seaborn.barplot('rewarded', 'stay', hue='rare', data=df.query('direct==False and T_interval==0.05 and n_intervals==20000 and N_state_action==500 and alpha==1.0'), order=['+', '-'])
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-15-57719a4a157e> in <module>()
# ----> 1 seaborn.barplot('rewarded', 'stay', hue='rare', data=df.query('direct==False and T_interval==0.05 and n_intervals==20000 and N_state_action==500 and alpha==1.0'), order=['+', '-'])
#
# /usr/local/lib/python2.7/dist-packages/seaborn/categorical.pyc in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, ax, **kwargs)
#    2897                           estimator, ci, n_boot, units,
#    2898                           orient, color, palette, saturation,
# -> 2899                           errcolor, errwidth, capsize)
#    2900
#    2901     if ax is None:
#
# /usr/local/lib/python2.7/dist-packages/seaborn/categorical.pyc in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize)
#    1541         """Initialize the plotter."""
#    1542         self.establish_variables(x, y, hue, data, orient,
# -> 1543                                  order, hue_order, units)
#    1544         self.establish_colors(color, palette, saturation)
#    1545         self.estimate_statistic(estimator, ci, n_boot)
#
# /usr/local/lib/python2.7/dist-packages/seaborn/categorical.pyc in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     201                 # Group the numeric data
#     202                 plot_data, value_label = self._group_longform(vals, groups,
# --> 203                                                               group_names)
#     204
#     205                 # Now handle the hue levels for nested ordering
#
# /usr/local/lib/python2.7/dist-packages/seaborn/categorical.pyc in _group_longform(self, vals, grouper, order)
#     247         for g in order:
#     248             try:
# --> 249                 g_vals = np.asarray(grouped_vals.get_group(g))
#     250             except KeyError:
#     251                 g_vals = np.array([])
#
# /usr/lib/python2.7/dist-packages/pandas/core/groupby.pyc in get_group(self, name, obj)
#     571             obj = self._selected_obj
#     572
# --> 573         inds = self._get_index(name)
#     574         return obj.take(inds, axis=self.axis, convert=False)
#     575
#
# /usr/lib/python2.7/dist-packages/pandas/core/groupby.pyc in _get_index(self, name)
#     427             return key
#     428
# --> 429         sample = next(iter(self.indices))
#     430         if isinstance(sample, tuple):
#     431             if not isinstance(name, tuple):
#
# StopIteration:

# %%
seaborn.barplot('rewarded', 'stay', hue='rare', data=df.query('rate==True and env_seed==1 and T_interval==0.002 and n_intervals==20000 and N_state_action==500 and alpha==1.0'), order=[True, False])

# %%
#seaborn.barplot('rewarded', 'stay', hue='rare', data=df.query('env_seed==2 and direct==False and T_interval==0.1 and n_intervals==20000 and seed==8'), order=[1, 0])

# %%
#seaborn.barplot('rewarded', 'stay', hue='rare', data=df.query('env_seed==2 and direct==False and T_interval==0.1 and n_intervals==20000 and seed==9'), order=[1, 0])

# %%
#seaborn.barplot('rewarded', 'stay', hue='rare', data=df.query('env_seed==2 and direct==False and T_interval==0.1 and n_intervals==20000 and seed==10'), order=[1, 0])

# %%
human_plot = seaborn.barplot('rewarded', 'stay', hue='rare', data=df.query('direct==False and T_interval==0.05 and n_intervals==20000 and alpha==0.3 and seed==1 and N_state_action==500'), order=[True, False])
#fig = human_plot.get_figure()
#fig.savefig("humanish_neuron.png")

# %%
human2 = seaborn.barplot('rewarded', 'stay', hue='rare', data=df.query('direct==False and T_interval==0.05 and n_intervals==20000 and alpha==0.3 and seed==2 and N_state_action==500'), order=[True, False])
#fig4 = human2.get_figure()
#fig4.savefig("humanish_neuron_seed2.png")

# %%
seaborn.barplot('rewarded', 'stay', hue='rare', data=df.query('direct==False and T_interval==0.05 and n_intervals==20000 and alpha==0.3 and seed==4 and N_state_action==500'), order=[True, False])

# %%
seaborn.barplot('rewarded', 'stay', hue='rare', data=df.query('direct==False and T_interval==0.05 and n_intervals==20000 and alpha==0.3 and seed==6 and N_state_action==500'), order=[True, False])

# %%
mb_plot = seaborn.barplot('rewarded', 'stay', hue='rare', data=df.query('direct==False and T_interval==0.05 and n_intervals==20000 and alpha==0.3 and seed==8 and N_state_action==500'), order=[True, False])
#fig2 = mb_plot.get_figure()
#fig2.savefig("model_based_neuron.png")

# %%
seaborn.barplot('rewarded', 'stay', hue='rare', data=df.query('direct==False and T_interval==0.05 and n_intervals==20000 and alpha==0.3 and seed==13 and N_state_action==500'), order=[True, False])

# %%
seaborn.barplot('rewarded', 'stay', hue='rare', data=df.query('direct==False and T_interval==0.05 and n_intervals==20000 and alpha==0.3 and seed==14 and N_state_action==500'), order=[True, False])

# %%
opp_plot = seaborn.barplot('rewarded', 'stay', hue='rare', data=df.query('direct==False and T_interval==0.05 and n_intervals==20000 and alpha==0.3 and seed==7 and N_state_action==500'), order=[True, False])
#fig3 = opp_plot.get_figure()
#fig3.savefig("opposite_neuron.png")

# %%
seaborn.barplot('rewarded', 'stay', hue='rare', data=df.query('direct==False and T_interval==0.05 and n_intervals==20000 and alpha==0.3 and seed==10 and N_state_action==500'), order=[True, False])

# %%
seaborn.barplot('rewarded', 'stay', hue='rare', data=df.query('direct==False and T_interval==0.05 and n_intervals==20000 and alpha==0.3 and seed==17 and N_state_action==500'), order=[True, False])

# %%
seaborn.barplot('rewarded', 'stay', hue='rare', data=df.query('direct==False and T_interval==0.05 and n_intervals==20000 and alpha==0.3 and seed==19 and N_state_action==500'), order=[True, False])

# %%
plot2 = seaborn.barplot('rewarded', 'stay', hue='rare', data=df.query('direct==False and T_interval==0.2 and n_intervals==20000 and alpha==0.3 and seed==1 and N_state_action==500'), order=[True, False])
#fig7 = plot2.get_figure()
#fig7.savefig("time_2.png")

# %%
plot5 = seaborn.barplot('rewarded', 'stay', hue='rare', data=df.query('direct==False and T_interval==0.5 and n_intervals==20000 and alpha==0.3 and seed==1 and N_state_action==500'), order=[True, False])
#fig8 = plot5.get_figure()
#fig8.savefig("time_5.png")

# %%
#plot51 = seaborn.barplot('rewarded', 'stay', hue='rare', data=df.query('direct==False and T_interval==0.51 and n_intervals==20000 and alpha==0.3 and seed==1 and N_state_action==500'), order=[True, False])
#fig9 = plot51.get_figure()
#fig9.savefig("time_51.png")

# %%
g =seaborn.factorplot(x='rewarded', y='stay', hue='rare', col='T_interval', data=df.query('n_intervals==20000 and N_product==200 and N_state_action==500 and direct==False and alpha==0.3'), kind='bar', order=[True, False], size=3)
g.set(ylim=(None, 1.0))

# %%
#seaborn.set_style("whitegrid")
#pylab.figure(figsize=(4,3))

#colors = seaborn.color_palette('deep', 2)
#palette = {
#    'C+': colors[0],
#    'R+': colors[1],
#    'C-': colors[0],
#    'R-': colors[1],
#}
vals=[0.01, 0.02, 0.03, 0.05, 0.1, 0.2, 0.3, 0.5]
seaborn.pointplot(x='T_interval', y='stay', hue='type',
                  data=df.query('alpha==0.3 and n_intervals==20000 and T_interval>=0.01 and N_product==200 and N_state_action==500 and direct==False'),
                  order=vals,
                  dodge=True,
                  hue_order=['C+', 'R+', 'C-', 'R-'],
                  linestyles=['-','-','--','--'],
                  palette=colors)
ax = pylab.gca()
pylab.legend(title='', loc='best', handles=ax.lines[::(len(vals)+1)], labels=['C+', 'R+', 'C-', 'R-'])
pylab.xlabel('T_interval')
pylab.ylabel('stay probability')
pylab.tight_layout()

# %%
seaborn.factorplot(x='rewarded', y='stay', hue='rare', col='T_interval', row='syn', data=df.query('seed==1 and syn>0.003 and syn!=0.017 and N_product==200 and n_intervals==20000 and alpha==0.3 and T_interval>0.03 and N_state_action==500'), kind='bar', order=['+', '-'], hue_order=['C','R'], size=3)

# %%
df.query('seed==1 and syn==0.049 and n_intervals==20000 and alpha==0.3 and T_interval==0.1 and N_state_action==500 and N_product==200')
# Out:
#        D  N_product  N_state_action  T_interval  alpha backend  choice_noise  \
# 12236  5        200             500         0.1    0.3   nengo          0.05
# 12237  5        200             500         0.1    0.3   nengo          0.05
# 12238  5        200             500         0.1    0.3   nengo          0.05
# 12239  5        200             500         0.1    0.3   nengo          0.05
#
#       direct     dt  env_seed  n_intervals neuron_type rare   rate rewarded  \
# 12236  False  0.001        22        20000     default    R  False        +
# 12237  False  0.001        22        20000     default    C  False        +
# 12238  False  0.001        22        20000     default    R  False        -
# 12239  False  0.001        22        20000     default    C  False        -
#
#        seed      stay    syn type
# 12236     1  0.854685  0.049   R+
# 12237     1  0.831204  0.049   C+
# 12238     1  0.907107  0.049   R-
# 12239     1  0.770559  0.049   C-
